# %%
# 需要安装以下包
# pip install pymupdf==1.18.19
# pip install python-docx
# pip install jieba

# %%
import os
import json
import pickle

from etils import epath
import pandas as pd
from tqdm import tqdm
import fitz
from docx import Document
from jieba import posseg


def char_pos_tag(text):
    words = pseg.cut(text)  # 使用jieba进行分词
    char_pos_tags = []
    for word, pos in words:
        pos = 1 if pos.startswith('n') else 0
        for char in word:
            char_pos_tags.append((char, pos))
    return char_pos_tags

# %% [markdown]
# # CMDD - 多轮实体对话

# %%
def deal_file(path, name='', mode='train'):
    with path.open('r') as f:
        data = json.load(f)
        text = ''
        ners = []
        for dialogue in data['dialogue-content']:
            speaker = dialogue['speaker'].strip()
            sentence = dialogue['sentence'].strip()
            text += f'{speaker}:{sentence}\n'
            prefix = (len(speaker) + 1) * [0]
            ner = [1 if l.strip().startswith(('B', 'I')) else 0 for l in dialogue['label']]
            ner = prefix + ner + [0]
            ners.extend(ner)
    assert len(ners) == len(text), print(len(ners), len(text))
    pos_tags = char_pos_tag(text)
    tokens, poss = zip(*pos_tags)
    assert len(tokens) == len(text) == len(poss) == len(ners)
    result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': ners, 'length': len(text), 
              'name': name, 'mode': mode}
    return result

name = 'CMDD'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
for mode in ['train', 'dev', 'test']:
    read_dir = epath.Path('../data/CMDD-多轮实体对话/')  / mode
    files = os.listdir(read_dir)
    print(f'mode: {mode} length: {len(files)}')
    for file in files:
        abs_path = read_dir / file
        data = deal_file(abs_path, name=name, mode=mode)
        writer.write(f'{data}\n')
writer.close()
# Out:
# mode: train length: 1241
# mode: dev length: 413
# mode: test length: 413

# %% [markdown]
# # IMCS - 多轮实体对话

# %%
def deal_file(path, name='', mode='train'):
    results = []
    with path.open('r') as f:
        data = json.load(f)
        for id, message in data.items():
            self_report = message['self_report']
            text = f'患者: {self_report}\n'
            ners = [0] * len(text)
            for dialogue in message['dialogue']:
                speaker = dialogue['speaker'].strip()
                sentence = dialogue['sentence'].strip()
                prefix = (len(speaker) + 1) * [0]
                if mode != 'test':
                    ner = [1 if l.strip().startswith(('B', 'I')) else 0 for l in dialogue['BIO_label'].split()]
                    assert len(ner) == len(sentence), print(len(ner), len(sentence))
                    ner = prefix + ner + [0]
                else:
                    ner = len(f'{speaker}:{sentence}\n') * [0]
                    assert len(ner) == len(sentence) + 4, print(len(ner), len(sentence))
                    
                ners.extend(ner)
                text += f'{speaker}:{sentence}\n'
                
            assert len(ners) == len(text), print(len(ners), len(text))
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss) == len(ners)
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': ners, 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
    return results

name = 'IMCS'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
# test 没有实体标签
for mode in ['train', 'dev', 'test']:
    abs_path = epath.Path('../data/IMCS-IR-多轮实体对话/')  / f'IMCS_{mode}.json'
    data = deal_file(abs_path, name=name, mode=mode)
    print(f'mode: {mode} length: {len(data)}')
    if isinstance(data, list):
        for d in data:
            writer.write(f'{d}\n')
writer.close()
# Out:
# mode: train length: 1824
# mode: dev length: 616
# mode: test length: 612

# %% [markdown]
# # CY - 多轮对话

# %%
def deal_file(path, name='', mode='train'):
    with path.open('rb') as f:
        data = pickle.load(f)
#         print(f'N: {len(data)}')
        results = []
        for d in data:
            history = ''
            ners = []
            for i, his in enumerate(d['history']):
                his += '\n'
                ner = d['tags'][i] + [-1]
                ner = [0 if l == -1 else 1 for l in ner]
                history += his
                ners.extend(ner)
            assert len(history) == len(ners)
            response = d['response']
            ners += [0] * len(response)
            
            text = history + response
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss) == len(ners)
            
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': ners, 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
        return results
     
name = 'CY'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
for mode in ['train', 'dev']:
    read_dir = epath.Path(f'../data/cy-多轮对话/old_dis_pk_dir/{mode}')
    files = os.listdir(read_dir)
    length = 0
    for file in files:
        abs_path = read_dir / file
        data = deal_file(abs_path, name=name, mode=mode)
        length += len(data)
        if isinstance(data, list):
            for d in data:
                writer.write(f'{d}\n')
    print(f'mode: {mode} length: {length}')
writer.close()
# Out:
# mode: train length: 218220
# mode: dev length: 2735

# %% [markdown]
# # CHIP - 多轮实体对话

# %%
def deal_file(path, name='', mode='train'):
    results = []
    with path.open('r') as f:
        for line in f:
            line = json.loads(line)
            text = ''
            ners = []
            for dialogue in line['dialog_info']:
                speaker = dialogue['sender'].strip()
                sentence = dialogue['text']
                prefix = (len(speaker) + 1) * [0]
                text += f'{speaker}:{sentence}\n'
                ner = [0] * len(sentence)
                for r in dialogue['ner']:
                    index = r['range']
                    if index[1] > len(sentence):
                        index[1] = len(sentence)
                    ner[index[0]: index[1]] = [1] *(index[1] - index[0])
                assert len(ner) == len(sentence), print(len(ner), len(sentence), dialogue, ner)
                ner = prefix + ner + [0]
                ners.extend(ner)
            assert len(ners) == len(text), print(ners, text)
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss) == len(ners)
            
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': ners, 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
    return results
            
name = 'CHIP' 
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
# test 没有实体标签
for mode in ['train', 'dev', 'test']:
    abs_path = epath.Path(f'../data/CHIP-MDCFNPC-多轮对话实体/CHIP-MDCFNPC_{mode}.jsonl')
    data = deal_file(abs_path, name=name, mode=mode)
    print(f'mode: {mode} length: {len(data)}')
    if isinstance(data, list):
        for d in data:
            writer.write(f'{d}\n')
writer.close()
# Out:
# mode: train length: 5000
# mode: dev length: 1000
# mode: test length: 2000

# %% [markdown]
# # fd-subset

# %%
def deal_file(path, name='', mode='train'):
    with path.open('rb') as f:
        data = pickle.load(f)
        results = []
        for d in data:
            history = ''
            ners = []
            for i, his in enumerate(d['history']):
                his += '\n'
                ner = d['tags'][i] + [-1]
                ner = [0 if l == -1 else 1 for l in ner]
                history += his
                ners.extend(ner)
            assert len(history) == len(ners)
            response = d['response']
            ners += [0] * len(response)
            
            text = history + response
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss) == len(ners)
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': ners, 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
        return results
     
name = 'fd-subset'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
for mode in ['train', 'dev']:
    abs_path = epath.Path(f'../data/fd-subset-多轮/{mode}.pk')
    data = deal_file(abs_path, name=name, mode=mode)
    print(f'mode: {mode} length: {len(data)}')
    if isinstance(data, list):
        for d in data:
            writer.write(f'{d}\n')
writer.close()
# Out:
# mode: train length: 6317
# mode: dev length: 1771

# %% [markdown]
# # MedDG-多轮对话

# %%
def deal_train_file(path, name='', mode='train'):
    results = []
    with path.open('r') as f:
        data = json.load(f)
        for dialogues in data:
            text = ''
            for dialogue in dialogues:
#                 return dialogue
                speaker = '病人:' if dialogue['id'] == 'Patient' else '医生:'
                sentence = dialogue['Sentence']
                prefix = (len(speaker) + 1) * [0]
                text += f'{speaker}:{sentence}\n'
                    
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss)
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
    return results


def deal_dev_file(path, name='', mode='train'):
    results = []
    with path.open('r') as f:
        data = json.load(f)
        for dialogue in data:
            sentence = dialogue['history']
            output = f'医生:{dialogue["output"]}'
            sentence.append(output)
            text = '\n'.join(sentence)
            
            pos_tags = char_pos_tag(text)
            tokens, poss = zip(*pos_tags)
            assert len(tokens) == len(text) == len(poss)
            result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                      'name': name, 'mode': mode}
            results.append(result)
    return results

name = 'MedDG'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
for mode in ['train', 'dev']:
    abs_path = epath.Path(f'../data/MedDG-多轮对话/MedDG_{mode}.json')
    if mode == 'train':
        data = deal_train_file(abs_path, name=name, mode=mode)
    else:
        data = deal_dev_file(abs_path, name=name, mode=mode)
        
    print(f'mode: {mode} length: {len(data)}')
    if isinstance(data, list):
        for d in data:
            writer.write(f'{d}\n')
writer.close()
# Out:
# mode: train length: 17864
# mode: dev length: 2747

# %% [markdown]
# # data/cMQA-master/answers.csv

# %%
def deal_file(question_path, answers_path, name='', mode='train'):
    questions = pd.read_csv(question_path)
    answers = pd.read_csv(answers_path)
    results = []
    for q_id in tqdm(questions['question_id'].unique()):
        try:
            question = questions[questions['question_id'] == q_id]['content'].item()
            answer = answers[answers['question_id'] == q_id]['content'].item()
        except Exception as error:
            print(f'error: {error} q_id: {q_id}')
            continue
        if not question.strip() or not answer.strip():
            continue
        text = f'患者:{question}\n医生:{answer}'
        
        pos_tags = char_pos_tag(text)
        tokens, poss = zip(*pos_tags)
        assert len(tokens) == len(text) == len(poss)
        result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                  'name': name, 'mode': mode}
        results.append(result)
    return results
     
name = 'cMQA'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
question_path = epath.Path(f'../data/cMQA-master/questions.csv')
answers_path = epath.Path(f'../data/cMQA-master/answers.csv')

data = deal_file(question_path, answers_path, name=name, mode='total')
print(f'mode: total length: {len(data)}')
if isinstance(data, str):
    data = [data]
for d in data:
    writer.write(f'{d}\n')
    
writer.close()
# Out:
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 263249/268591 [23:07<00:05, 901.26it/s]
# error: can only convert an array of size 1 to a Python scalar q_id: 262945
# error: can only convert an array of size 1 to a Python scalar q_id: 262946
# error: can only convert an array of size 1 to a Python scalar q_id: 262947
# error: can only convert an array of size 1 to a Python scalar q_id: 262948
# error: can only convert an array of size 1 to a Python scalar q_id: 262949
# error: can only convert an array of size 1 to a Python scalar q_id: 262950
# error: can only convert an array of size 1 to a Python scalar q_id: 262951
# error: can only convert an array of size 1 to a Python scalar q_id: 262952
# error: can only convert an array of size 1 to a Python scalar q_id: 262953
# error: can only convert an array of size 1 to a Python scalar q_id: 262954
# error: can only convert an array of size 1 to a Python scalar q_id: 262955
# error: can only convert an array of size 1 to a Python scalar q_id: 262956
# error: can only convert an array of size 1 to a Python scalar q_id: 262957
# error: can only convert an array of size 1 to a Python scalar q_id: 262958
# error: can only convert an array of size 1 to a Python scalar q_id: 262959
# error: can only convert an array of size 1 to a Python scalar q_id: 262960
# error: can only convert an array of size 1 to a Python scalar q_id: 262961
# error: can only convert an array of size 1 to a Python scalar q_id: 262962
# error: can only convert an array of size 1 to a Python scalar q_id: 262963
# error: can only convert an array of size 1 to a Python scalar q_id: 262964
# error: can only convert an array of size 1 to a Python scalar q_id: 262965
# error: can only convert an array of size 1 to a Python scalar q_id: 262966
# error: can only convert an array of size 1 to a Python scalar q_id: 262967
# error: can only convert an array of size 1 to a Python scalar q_id: 262968
# error: can only convert an array of size 1 to a Python scalar q_id: 262969
# error: can only convert an array of size 1 to a Python scalar q_id: 262970
# error: can only convert an array of size 1 to a Python scalar q_id: 262971
# error: can only convert an array of size 1 to a Python scalar q_id: 262972
# error: can only convert an array of size 1 to a Python scalar q_id: 262973
# error: can only convert an array of size 1 to a Python scalar q_id: 262974
# error: can only convert an array of size 1 to a Python scalar q_id: 262975
# error: can only convert an array of size 1 to a Python scalar q_id: 262976
# error: can only convert an array of size 1 to a Python scalar q_id: 262977
# error: can only convert an array of size 1 to a Python scalar q_id: 262978
# error: can only convert an array of size 1 to a Python scalar q_id: 262979
# error: can only convert an array of size 1 to a Python scalar q_id: 262980
# error: can only convert an array of size 1 to a Python scalar q_id: 262981
# error: can only convert an array of size 1 to a Python scalar q_id: 262982
# error: can only convert an array of size 1 to a Python scalar q_id: 262983
# error: can only convert an array of size 1 to a Python scalar q_id: 262984
# error: can only convert an array of size 1 to a Python scalar q_id: 262985
# error: can only convert an array of size 1 to a Python scalar q_id: 262986
# error: can only convert an array of size 1 to a Python scalar q_id: 262987
# error: can only convert an array of size 1 to a Python scalar q_id: 262988
# error: can only convert an array of size 1 to a Python scalar q_id: 262989
# error: can only convert an array of size 1 to a Python scalar q_id: 262990
# error: can only convert an array of size 1 to a Python scalar q_id: 262991
# error: can only convert an array of size 1 to a Python scalar q_id: 262992
# error: can only convert an array of size 1 to a Python scalar q_id: 262993
# error: can only convert an array of size 1 to a Python scalar q_id: 262994
# error: can only convert an array of size 1 to a Python scalar q_id: 262995
# error: can only convert an array of size 1 to a Python scalar q_id: 262996
# error: can only convert an array of size 1 to a Python scalar q_id: 262997
# error: can only convert an array of size 1 to a Python scalar q_id: 262998
# error: can only convert an array of size 1 to a Python scalar q_id: 262999
# error: can only convert an array of size 1 to a Python scalar q_id: 263000
# error: can only convert an array of size 1 to a Python scalar q_id: 263001
# error: can only convert an array of size 1 to a Python scalar q_id: 263002
# error: can only convert an array of size 1 to a Python scalar q_id: 263003
# error: can only convert an array of size 1 to a Python scalar q_id: 263004
# error: can only convert an array of size 1 to a Python scalar q_id: 263005
# error: can only convert an array of size 1 to a Python scalar q_id: 263006
# error: can only convert an array of size 1 to a Python scalar q_id: 263007
# error: can only convert an array of size 1 to a Python scalar q_id: 263008
# error: can only convert an array of size 1 to a Python scalar q_id: 263009
# error: can only convert an array of size 1 to a Python scalar q_id: 263010
# error: can only convert an array of size 1 to a Python scalar q_id: 263011
# error: can only convert an array of size 1 to a Python scalar q_id: 263012
# error: can only convert an array of size 1 to a Python scalar q_id: 263013
# error: can only convert an array of size 1 to a Python scalar q_id: 263014
# error: can only convert an array of size 1 to a Python scalar q_id: 263015
# error: can only convert an array of size 1 to a Python scalar q_id: 263016
# error: can only convert an array of size 1 to a Python scalar q_id: 263017
# error: can only convert an array of size 1 to a Python scalar q_id: 263018
# error: can only convert an array of size 1 to a Python scalar q_id: 263019
# error: can only convert an array of size 1 to a Python scalar q_id: 263020
# error: can only convert an array of size 1 to a Python scalar q_id: 263021
# error: can only convert an array of size 1 to a Python scalar q_id: 263022
# error: can only convert an array of size 1 to a Python scalar q_id: 263023
# error: can only convert an array of size 1 to a Python scalar q_id: 263024
# error: can only convert an array of size 1 to a Python scalar q_id: 263025
# error: can only convert an array of size 1 to a Python scalar q_id: 263026
# error: can only convert an array of size 1 to a Python scalar q_id: 263027
# error: can only convert an array of size 1 to a Python scalar q_id: 263028
# error: can only convert an array of size 1 to a Python scalar q_id: 263029
# error: can only convert an array of size 1 to a Python scalar q_id: 263030
# error: can only convert an array of size 1 to a Python scalar q_id: 263031
# error: can only convert an array of size 1 to a Python scalar q_id: 263032
# error: can only convert an array of size 1 to a Python scalar q_id: 263033
# error: can only convert an array of size 1 to a Python scalar q_id: 263034
# error: can only convert an array of size 1 to a Python scalar q_id: 263035
# error: can only convert an array of size 1 to a Python scalar q_id: 263036
# error: can only convert an array of size 1 to a Python scalar q_id: 263037
# error: can only convert an array of size 1 to a Python scalar q_id: 263038
# error: can only convert an array of size 1 to a Python scalar q_id: 263039
# error: can only convert an array of size 1 to a Python scalar q_id: 263040
# error: can only convert an array of size 1 to a Python scalar q_id: 263041
# error: can only convert an array of size 1 to a Python scalar q_id: 263042
# error: can only convert an array of size 1 to a Python scalar q_id: 263043
# error: can only convert an array of size 1 to a Python scalar q_id: 263044
# error: can only convert an array of size 1 to a Python scalar q_id: 263045
# error: can only convert an array of size 1 to a Python scalar q_id: 263046
# error: can only convert an array of size 1 to a Python scalar q_id: 263047
# error: can only convert an array of size 1 to a Python scalar q_id: 263048
# error: can only convert an array of size 1 to a Python scalar q_id: 263049
# error: can only convert an array of size 1 to a Python scalar q_id: 263050
# error: can only convert an array of size 1 to a Python scalar q_id: 263051
# error: can only convert an array of size 1 to a Python scalar q_id: 263052
# error: can only convert an array of size 1 to a Python scalar q_id: 263053
# error: can only convert an array of size 1 to a Python scalar q_id: 263054
# error: can only convert an array of size 1 to a Python scalar q_id: 263055
# error: can only convert an array of size 1 to a Python scalar q_id: 263056
# error: can only convert an array of size 1 to a Python scalar q_id: 263057
# error: can only convert an array of size 1 to a Python scalar q_id: 263058
# error: can only convert an array of size 1 to a Python scalar q_id: 263059
# error: can only convert an array of size 1 to a Python scalar q_id: 263060
# error: can only convert an array of size 1 to a Python scalar q_id: 263061
# error: can only convert an array of size 1 to a Python scalar q_id: 263062
# error: can only convert an array of size 1 to a Python scalar q_id: 263063
# error: can only convert an array of size 1 to a Python scalar q_id: 263064
# error: can only convert an array of size 1 to a Python scalar q_id: 263065
# error: can only convert an array of size 1 to a Python scalar q_id: 263066
# error: can only convert an array of size 1 to a Python scalar q_id: 263067
# error: can only convert an array of size 1 to a Python scalar q_id: 263068
# error: can only convert an array of size 1 to a Python scalar q_id: 263069
# error: can only convert an array of size 1 to a Python scalar q_id: 263070
# error: can only convert an array of size 1 to a Python scalar q_id: 263071
# error: can only convert an array of size 1 to a Python scalar q_id: 263072
# error: can only convert an array of size 1 to a Python scalar q_id: 263073
# error: can only convert an array of size 1 to a Python scalar q_id: 263074
# error: can only convert an array of size 1 to a Python scalar q_id: 263075
# error: can only convert an array of size 1 to a Python scalar q_id: 263076
# error: can only convert an array of size 1 to a Python scalar q_id: 263077
# error: can only convert an array of size 1 to a Python scalar q_id: 263078
# error: can only convert an array of size 1 to a Python scalar q_id: 263079
# error: can only convert an array of size 1 to a Python scalar q_id: 263080
# error: can only convert an array of size 1 to a Python scalar q_id: 263081
# error: can only convert an array of size 1 to a Python scalar q_id: 263082
# error: can only convert an array of size 1 to a Python scalar q_id: 263083
# error: can only convert an array of size 1 to a Python scalar q_id: 263084
# error: can only convert an array of size 1 to a Python scalar q_id: 263085
# error: can only convert an array of size 1 to a Python scalar q_id: 263086
# error: can only convert an array of size 1 to a Python scalar q_id: 263087
# error: can only convert an array of size 1 to a Python scalar q_id: 263088
# error: can only convert an array of size 1 to a Python scalar q_id: 263089
# error: can only convert an array of size 1 to a Python scalar q_id: 263090
# error: can only convert an array of size 1 to a Python scalar q_id: 263091
# error: can only convert an array of size 1 to a Python scalar q_id: 263092
# error: can only convert an array of size 1 to a Python scalar q_id: 263093
# error: can only convert an array of size 1 to a Python scalar q_id: 263094
# error: can only convert an array of size 1 to a Python scalar q_id: 263095
# error: can only convert an array of size 1 to a Python scalar q_id: 263096
# error: can only convert an array of size 1 to a Python scalar q_id: 263097
# error: can only convert an array of size 1 to a Python scalar q_id: 263098
# error: can only convert an array of size 1 to a Python scalar q_id: 263099
# error: can only convert an array of size 1 to a Python scalar q_id: 263100
# error: can only convert an array of size 1 to a Python scalar q_id: 263101
# error: can only convert an array of size 1 to a Python scalar q_id: 263102
# error: can only convert an array of size 1 to a Python scalar q_id: 263103
# error: can only convert an array of size 1 to a Python scalar q_id: 263104
# error: can only convert an array of size 1 to a Python scalar q_id: 263105
# error: can only convert an array of size 1 to a Python scalar q_id: 263106
# error: can only convert an array of size 1 to a Python scalar q_id: 263107
# error: can only convert an array of size 1 to a Python scalar q_id: 263108
# error: can only convert an array of size 1 to a Python scalar q_id: 263109
# error: can only convert an array of size 1 to a Python scalar q_id: 263110
# error: can only convert an array of size 1 to a Python scalar q_id: 263111
# error: can only convert an array of size 1 to a Python scalar q_id: 263112
# error: can only convert an array of size 1 to a Python scalar q_id: 263113
# error: can only convert an array of size 1 to a Python scalar q_id: 263114
# error: can only convert an array of size 1 to a Python scalar q_id: 263115
# error: can only convert an array of size 1 to a Python scalar q_id: 263116
# error: can only convert an array of size 1 to a Python scalar q_id: 263117
# error: can only convert an array of size 1 to a Python scalar q_id: 263118
# error: can only convert an array of size 1 to a Python scalar q_id: 263119
# error: can only convert an array of size 1 to a Python scalar q_id: 263120
# error: can only convert an array of size 1 to a Python scalar q_id: 263121
# error: can only convert an array of size 1 to a Python scalar q_id: 263122
# error: can only convert an array of size 1 to a Python scalar q_id: 263123
# error: can only convert an array of size 1 to a Python scalar q_id: 263124
# error: can only convert an array of size 1 to a Python scalar q_id: 263125
# error: can only convert an array of size 1 to a Python scalar q_id: 263126
# error: can only convert an array of size 1 to a Python scalar q_id: 263127
# error: can only convert an array of size 1 to a Python scalar q_id: 263128
# error: can only convert an array of size 1 to a Python scalar q_id: 263129
# error: can only convert an array of size 1 to a Python scalar q_id: 263130
# error: can only convert an array of size 1 to a Python scalar q_id: 263131
# error: can only convert an array of size 1 to a Python scalar q_id: 263132
# error: can only convert an array of size 1 to a Python scalar q_id: 263133
# error: can only convert an array of size 1 to a Python scalar q_id: 263134
# error: can only convert an array of size 1 to a Python scalar q_id: 263135
# error: can only convert an array of size 1 to a Python scalar q_id: 263136
# error: can only convert an array of size 1 to a Python scalar q_id: 263137
# error: can only convert an array of size 1 to a Python scalar q_id: 263138
# error: can only convert an array of size 1 to a Python scalar q_id: 263139
# error: can only convert an array of size 1 to a Python scalar q_id: 263140
# error: can only convert an array of size 1 to a Python scalar q_id: 263141
# error: can only convert an array of size 1 to a Python scalar q_id: 263142
# error: can only convert an array of size 1 to a Python scalar q_id: 263143
# error: can only convert an array of size 1 to a Python scalar q_id: 263144
# error: can only convert an array of size 1 to a Python scalar q_id: 263145
# error: can only convert an array of size 1 to a Python scalar q_id: 263146
# error: can only convert an array of size 1 to a Python scalar q_id: 263147
# error: can only convert an array of size 1 to a Python scalar q_id: 263148
# error: can only convert an array of size 1 to a Python scalar q_id: 263149
# error: can only convert an array of size 1 to a Python scalar q_id: 263150
# error: can only convert an array of size 1 to a Python scalar q_id: 263151
# error: can only convert an array of size 1 to a Python scalar q_id: 263152
# error: can only convert an array of size 1 to a Python scalar q_id: 263153
# error: can only convert an array of size 1 to a Python scalar q_id: 263154
# error: can only convert an array of size 1 to a Python scalar q_id: 263155
# error: can only convert an array of size 1 to a Python scalar q_id: 263156
# error: can only convert an array of size 1 to a Python scalar q_id: 263157
# error: can only convert an array of size 1 to a Python scalar q_id: 263158
# error: can only convert an array of size 1 to a Python scalar q_id: 263159
# error: can only convert an array of size 1 to a Python scalar q_id: 263160
# error: can only convert an array of size 1 to a Python scalar q_id: 263161
# error: can only convert an array of size 1 to a Python scalar q_id: 263162
# error: can only convert an array of size 1 to a Python scalar q_id: 263163
# error: can only convert an array of size 1 to a Python scalar q_id: 263164
# error: can only convert an array of size 1 to a Python scalar q_id: 263165
# error: can only convert an array of size 1 to a Python scalar q_id: 263166
# error: can only convert an array of size 1 to a Python scalar q_id: 263167
# error: can only convert an array of size 1 to a Python scalar q_id: 263168
# error: can only convert an array of size 1 to a Python scalar q_id: 263169
# error: can only convert an array of size 1 to a Python scalar q_id: 263170
# error: can only convert an array of size 1 to a Python scalar q_id: 263171
# error: can only convert an array of size 1 to a Python scalar q_id: 263172
# error: can only convert an array of size 1 to a Python scalar q_id: 263173
# error: can only convert an array of size 1 to a Python scalar q_id: 263174
# error: can only convert an array of size 1 to a Python scalar q_id: 263175
# error: can only convert an array of size 1 to a Python scalar q_id: 263176
# error: can only convert an array of size 1 to a Python scalar q_id: 263177
# error: can only convert an array of size 1 to a Python scalar q_id: 263178
# error: can only convert an array of size 1 to a Python scalar q_id: 263179
# error: can only convert an array of size 1 to a Python scalar q_id: 263180
# error: can only convert an array of size 1 to a Python scalar q_id: 263181
# error: can only convert an array of size 1 to a Python scalar q_id: 263182
# error: can only convert an array of size 1 to a Python scalar q_id: 263183
# error: can only convert an array of size 1 to a Python scalar q_id: 263184
# error: can only convert an array of size 1 to a Python scalar q_id: 263185
# error: can only convert an array of size 1 to a Python scalar q_id: 263186
# error: can only convert an array of size 1 to a Python scalar q_id: 263187
# error: can only convert an array of size 1 to a Python scalar q_id: 263188
# error: can only convert an array of size 1 to a Python scalar q_id: 263189
# error: can only convert an array of size 1 to a Python scalar q_id: 263190
# error: can only convert an array of size 1 to a Python scalar q_id: 263191
# error: can only convert an array of size 1 to a Python scalar q_id: 263192
# error: can only convert an array of size 1 to a Python scalar q_id: 263193
# error: can only convert an array of size 1 to a Python scalar q_id: 263194
# error: can only convert an array of size 1 to a Python scalar q_id: 263195
# error: can only convert an array of size 1 to a Python scalar q_id: 263196
# error: can only convert an array of size 1 to a Python scalar q_id: 263197
# error: can only convert an array of size 1 to a Python scalar q_id: 263198
# error: can only convert an array of size 1 to a Python scalar q_id: 263199
# error: can only convert an array of size 1 to a Python scalar q_id: 263200
# error: can only convert an array of size 1 to a Python scalar q_id: 263201
# error: can only convert an array of size 1 to a Python scalar q_id: 263202
# error: can only convert an array of size 1 to a Python scalar q_id: 263203
# error: can only convert an array of size 1 to a Python scalar q_id: 263204
# error: can only convert an array of size 1 to a Python scalar q_id: 263205
# error: can only convert an array of size 1 to a Python scalar q_id: 263206
# error: can only convert an array of size 1 to a Python scalar q_id: 263207
# error: can only convert an array of size 1 to a Python scalar q_id: 263208
# error: can only convert an array of size 1 to a Python scalar q_id: 263209
# error: can only convert an array of size 1 to a Python scalar q_id: 263210
# error: can only convert an array of size 1 to a Python scalar q_id: 263211
# error: can only convert an array of size 1 to a Python scalar q_id: 263212
# error: can only convert an array of size 1 to a Python scalar q_id: 263213
# error: can only convert an array of size 1 to a Python scalar q_id: 263214
# error: can only convert an array of size 1 to a Python scalar q_id: 263215
# error: can only convert an array of size 1 to a Python scalar q_id: 263216
# error: can only convert an array of size 1 to a Python scalar q_id: 263217
# error: can only convert an array of size 1 to a Python scalar q_id: 263218
# error: can only convert an array of size 1 to a Python scalar q_id: 263219
# error: can only convert an array of size 1 to a Python scalar q_id: 263220
# error: can only convert an array of size 1 to a Python scalar q_id: 263221
# error: can only convert an array of size 1 to a Python scalar q_id: 263222
# error: can only convert an array of size 1 to a Python scalar q_id: 263223
# error: can only convert an array of size 1 to a Python scalar q_id: 263224
# error: can only convert an array of size 1 to a Python scalar q_id: 263225
# error: can only convert an array of size 1 to a Python scalar q_id: 263226
# error: can only convert an array of size 1 to a Python scalar q_id: 263227
# error: can only convert an array of size 1 to a Python scalar q_id: 263228
# error: can only convert an array of size 1 to a Python scalar q_id: 263229
# error: can only convert an array of size 1 to a Python scalar q_id: 263230
# error: can only convert an array of size 1 to a Python scalar q_id: 263231
# error: can only convert an array of size 1 to a Python scalar q_id: 263232
# error: can only convert an array of size 1 to a Python scalar q_id: 263233
# error: can only convert an array of size 1 to a Python scalar q_id: 263234
# error: can only convert an array of size 1 to a Python scalar q_id: 263235
# error: can only convert an array of size 1 to a Python scalar q_id: 263236
# error: can only convert an array of size 1 to a Python scalar q_id: 263237
# error: can only convert an array of size 1 to a Python scalar q_id: 263238
# error: can only convert an array of size 1 to a Python scalar q_id: 263239
# error: can only convert an array of size 1 to a Python scalar q_id: 263240
# error: can only convert an array of size 1 to a Python scalar q_id: 263241
# error: can only convert an array of size 1 to a Python scalar q_id: 263242
# error: can only convert an array of size 1 to a Python scalar q_id: 263243
# error: can only convert an array of size 1 to a Python scalar q_id: 263244
# error: can only convert an array of size 1 to a Python scalar q_id: 263245
# error: can only convert an array of size 1 to a Python scalar q_id: 263246
# error: can only convert an array of size 1 to a Python scalar q_id: 263247
# error: can only convert an array of size 1 to a Python scalar q_id: 263248
# error: can only convert an array of size 1 to a Python scalar q_id: 263249
# error: can only convert an array of size 1 to a Python scalar q_id: 263250
# error: can only convert an array of size 1 to a Python scalar q_id: 263251
# error: can only convert an array of size 1 to a Python scalar q_id: 263252
# error: can only convert an array of size 1 to a Python scalar q_id: 263253
# error: can only convert an array of size 1 to a Python scalar q_id: 263254
# error: can only convert an array of size 1 to a Python scalar q_id: 263255
# error: can only convert an array of size 1 to a Python scalar q_id: 263256
# error: can only convert an array of size 1 to a Python scalar q_id: 263257
# error: can only convert an array of size 1 to a Python scalar q_id: 263258
# error: can only convert an array of size 1 to a Python scalar q_id: 263259
# error: can only convert an array of size 1 to a Python scalar q_id: 263260
# error: can only convert an array of size 1 to a Python scalar q_id: 263261
# error: can only convert an array of size 1 to a Python scalar q_id: 263262
# error: can only convert an array of size 1 to a Python scalar q_id: 263263
# error: can only convert an array of size 1 to a Python scalar q_id: 263264
# error: can only convert an array of size 1 to a Python scalar q_id: 263265
# error: can only convert an array of size 1 to a Python scalar q_id: 263266
# error: can only convert an array of size 1 to a Python scalar q_id: 263267
# error: can only convert an array of size 1 to a Python scalar q_id: 263268
# error: can only convert an array of size 1 to a Python scalar q_id: 263269
# error: can only convert an array of size 1 to a Python scalar q_id: 263270
# error: can only convert an array of size 1 to a Python scalar q_id: 263271
# error: can only convert an array of size 1 to a Python scalar q_id: 263272
# error: can only convert an array of size 1 to a Python scalar q_id: 263273
# error: can only convert an array of size 1 to a Python scalar q_id: 263274
# error: can only convert an array of size 1 to a Python scalar q_id: 263275
# error: can only convert an array of size 1 to a Python scalar q_id: 263276
# error: can only convert an array of size 1 to a Python scalar q_id: 263277
# error: can only convert an array of size 1 to a Python scalar q_id: 263278
# error: can only convert an array of size 1 to a Python scalar q_id: 263279
# error: can only convert an array of size 1 to a Python scalar q_id: 263280
# error: can only convert an array of size 1 to a Python scalar q_id: 263281
# error: can only convert an array of size 1 to a Python scalar q_id: 263282
# error: can only convert an array of size 1 to a Python scalar q_id: 263283
# error: can only convert an array of size 1 to a Python scalar q_id: 263284
# error: can only convert an array of size 1 to a Python scalar q_id: 263285
# error: can only convert an array of size 1 to a Python scalar q_id: 263286
# error: can only convert an array of size 1 to a Python scalar q_id: 263287
# error: can only convert an array of size 1 to a Python scalar q_id: 263288
# error: can only convert an array of size 1 to a Python scalar q_id: 263289
# error: can only convert an array of size 1 to a Python scalar q_id: 263290
# error: can only convert an array of size 1 to a Python scalar q_id: 263291
# error: can only convert an array of size 1 to a Python scalar q_id: 263292
# error: can only convert an array of size 1 to a Python scalar q_id: 263293
# error: can only convert an array of size 1 to a Python scalar q_id: 263294
# error: can only convert an array of size 1 to a Python scalar q_id: 263295
# error: can only convert an array of size 1 to a Python scalar q_id: 263296
# error: can only convert an array of size 1 to a Python scalar q_id: 263297
# error: can only convert an array of size 1 to a Python scalar q_id: 263298
# error: can only convert an array of size 1 to a Python scalar q_id: 263299
# error: can only convert an array of size 1 to a Python scalar q_id: 263300
# error: can only convert an array of size 1 to a Python scalar q_id: 263301
# error: can only convert an array of size 1 to a Python scalar q_id: 263302
# error: can only convert an array of size 1 to a Python scalar q_id: 263303
# error: can only convert an array of size 1 to a Python scalar q_id: 263304
# error: can only convert an array of size 1 to a Python scalar q_id: 263305
# error: can only convert an array of size 1 to a Python scalar q_id: 263306
# error: can only convert an array of size 1 to a Python scalar q_id: 263307
# error: can only convert an array of size 1 to a Python scalar q_id: 263308
# error: can only convert an array of size 1 to a Python scalar q_id: 263309
# error: can only convert an array of size 1 to a Python scalar q_id: 263310
# error: can only convert an array of size 1 to a Python scalar q_id: 263311
# error: can only convert an array of size 1 to a Python scalar q_id: 263312
# error: can only convert an array of size 1 to a Python scalar q_id: 263313
# error: can only convert an array of size 1 to a Python scalar q_id: 263314
# error: can only convert an array of size 1 to a Python scalar q_id: 263315
# error: can only convert an array of size 1 to a Python scalar q_id: 263316
# error: can only convert an array of size 1 to a Python scalar q_id: 263317
# error: can only convert an array of size 1 to a Python scalar q_id: 263318
# error: can only convert an array of size 1 to a Python scalar q_id: 263319
# error: can only convert an array of size 1 to a Python scalar q_id: 263320
# error: can only convert an array of size 1 to a Python scalar q_id: 263321
# error: can only convert an array of size 1 to a Python scalar q_id: 263322
# error: can only convert an array of size 1 to a Python scalar q_id: 263323
# error: can only convert an array of size 1 to a Python scalar q_id: 263324
#  98%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊    | 263615/268591 [23:07<00:03, 1365.72it/s]
# error: can only convert an array of size 1 to a Python scalar q_id: 263325
# error: can only convert an array of size 1 to a Python scalar q_id: 263326
# error: can only convert an array of size 1 to a Python scalar q_id: 263327
# error: can only convert an array of size 1 to a Python scalar q_id: 263328
# error: can only convert an array of size 1 to a Python scalar q_id: 263329
# error: can only convert an array of size 1 to a Python scalar q_id: 263330
# error: can only convert an array of size 1 to a Python scalar q_id: 263331
# error: can only convert an array of size 1 to a Python scalar q_id: 263332
# error: can only convert an array of size 1 to a Python scalar q_id: 263333
# error: can only convert an array of size 1 to a Python scalar q_id: 263334
# error: can only convert an array of size 1 to a Python scalar q_id: 263335
# error: can only convert an array of size 1 to a Python scalar q_id: 263336
# error: can only convert an array of size 1 to a Python scalar q_id: 263337
# error: can only convert an array of size 1 to a Python scalar q_id: 263338
# error: can only convert an array of size 1 to a Python scalar q_id: 263339
# error: can only convert an array of size 1 to a Python scalar q_id: 263340
# error: can only convert an array of size 1 to a Python scalar q_id: 263341
# error: can only convert an array of size 1 to a Python scalar q_id: 263342
# error: can only convert an array of size 1 to a Python scalar q_id: 263343
# error: can only convert an array of size 1 to a Python scalar q_id: 263344
# error: can only convert an array of size 1 to a Python scalar q_id: 263345
# error: can only convert an array of size 1 to a Python scalar q_id: 263346
# error: can only convert an array of size 1 to a Python scalar q_id: 263347
# error: can only convert an array of size 1 to a Python scalar q_id: 263348
# error: can only convert an array of size 1 to a Python scalar q_id: 263349
# error: can only convert an array of size 1 to a Python scalar q_id: 263350
# error: can only convert an array of size 1 to a Python scalar q_id: 263351
# error: can only convert an array of size 1 to a Python scalar q_id: 263352
# error: can only convert an array of size 1 to a Python scalar q_id: 263353
# error: can only convert an array of size 1 to a Python scalar q_id: 263354
# error: can only convert an array of size 1 to a Python scalar q_id: 263355
# error: can only convert an array of size 1 to a Python scalar q_id: 263356
# error: can only convert an array of size 1 to a Python scalar q_id: 263357
# error: can only convert an array of size 1 to a Python scalar q_id: 263358
# error: can only convert an array of size 1 to a Python scalar q_id: 263359
# error: can only convert an array of size 1 to a Python scalar q_id: 263360
# error: can only convert an array of size 1 to a Python scalar q_id: 263361
# error: can only convert an array of size 1 to a Python scalar q_id: 263362
# error: can only convert an array of size 1 to a Python scalar q_id: 263363
# error: can only convert an array of size 1 to a Python scalar q_id: 263364
# error: can only convert an array of size 1 to a Python scalar q_id: 263365
# error: can only convert an array of size 1 to a Python scalar q_id: 263366
# error: can only convert an array of size 1 to a Python scalar q_id: 263367
# error: can only convert an array of size 1 to a Python scalar q_id: 263368
# error: can only convert an array of size 1 to a Python scalar q_id: 263369
# error: can only convert an array of size 1 to a Python scalar q_id: 263370
# error: can only convert an array of size 1 to a Python scalar q_id: 263371
# error: can only convert an array of size 1 to a Python scalar q_id: 263372
# error: can only convert an array of size 1 to a Python scalar q_id: 263373
# error: can only convert an array of size 1 to a Python scalar q_id: 263374
# error: can only convert an array of size 1 to a Python scalar q_id: 263375
# error: can only convert an array of size 1 to a Python scalar q_id: 263376
# error: can only convert an array of size 1 to a Python scalar q_id: 263377
# error: can only convert an array of size 1 to a Python scalar q_id: 263378
# error: can only convert an array of size 1 to a Python scalar q_id: 263379
# error: can only convert an array of size 1 to a Python scalar q_id: 263380
# error: can only convert an array of size 1 to a Python scalar q_id: 263381
# error: can only convert an array of size 1 to a Python scalar q_id: 263382
# error: can only convert an array of size 1 to a Python scalar q_id: 263383
# error: can only convert an array of size 1 to a Python scalar q_id: 263384
# error: can only convert an array of size 1 to a Python scalar q_id: 263385
# error: can only convert an array of size 1 to a Python scalar q_id: 263386
# error: can only convert an array of size 1 to a Python scalar q_id: 263387
# error: can only convert an array of size 1 to a Python scalar q_id: 263388
# error: can only convert an array of size 1 to a Python scalar q_id: 263389
# error: can only convert an array of size 1 to a Python scalar q_id: 263390
# error: can only convert an array of size 1 to a Python scalar q_id: 263391
# error: can only convert an array of size 1 to a Python scalar q_id: 263392
# error: can only convert an array of size 1 to a Python scalar q_id: 263393
# error: can only convert an array of size 1 to a Python scalar q_id: 263394
# error: can only convert an array of size 1 to a Python scalar q_id: 263395
# error: can only convert an array of size 1 to a Python scalar q_id: 263396
# error: can only convert an array of size 1 to a Python scalar q_id: 263397
# error: can only convert an array of size 1 to a Python scalar q_id: 263398
# error: can only convert an array of size 1 to a Python scalar q_id: 263399
# error: can only convert an array of size 1 to a Python scalar q_id: 263400
# error: can only convert an array of size 1 to a Python scalar q_id: 263401
# error: can only convert an array of size 1 to a Python scalar q_id: 263402
# error: can only convert an array of size 1 to a Python scalar q_id: 263403
# error: can only convert an array of size 1 to a Python scalar q_id: 263404
# error: can only convert an array of size 1 to a Python scalar q_id: 263405
# error: can only convert an array of size 1 to a Python scalar q_id: 263406
# error: can only convert an array of size 1 to a Python scalar q_id: 263407
# error: can only convert an array of size 1 to a Python scalar q_id: 263408
# error: can only convert an array of size 1 to a Python scalar q_id: 263409
# error: can only convert an array of size 1 to a Python scalar q_id: 263410
# error: can only convert an array of size 1 to a Python scalar q_id: 263411
# error: can only convert an array of size 1 to a Python scalar q_id: 263412
# error: can only convert an array of size 1 to a Python scalar q_id: 263413
# error: can only convert an array of size 1 to a Python scalar q_id: 263414
# error: can only convert an array of size 1 to a Python scalar q_id: 263415
# error: can only convert an array of size 1 to a Python scalar q_id: 263416
# error: can only convert an array of size 1 to a Python scalar q_id: 263417
# error: can only convert an array of size 1 to a Python scalar q_id: 263418
# error: can only convert an array of size 1 to a Python scalar q_id: 263419
# error: can only convert an array of size 1 to a Python scalar q_id: 263420
# error: can only convert an array of size 1 to a Python scalar q_id: 263421
# error: can only convert an array of size 1 to a Python scalar q_id: 263422
# error: can only convert an array of size 1 to a Python scalar q_id: 263423
# error: can only convert an array of size 1 to a Python scalar q_id: 263424
# error: can only convert an array of size 1 to a Python scalar q_id: 263425
# error: can only convert an array of size 1 to a Python scalar q_id: 263426
# error: can only convert an array of size 1 to a Python scalar q_id: 263427
# error: can only convert an array of size 1 to a Python scalar q_id: 263428
# error: can only convert an array of size 1 to a Python scalar q_id: 263429
# error: can only convert an array of size 1 to a Python scalar q_id: 263430
# error: can only convert an array of size 1 to a Python scalar q_id: 263431
# error: can only convert an array of size 1 to a Python scalar q_id: 263432
# error: can only convert an array of size 1 to a Python scalar q_id: 263433
# error: can only convert an array of size 1 to a Python scalar q_id: 263434
# error: can only convert an array of size 1 to a Python scalar q_id: 263435
# error: can only convert an array of size 1 to a Python scalar q_id: 263436
# error: can only convert an array of size 1 to a Python scalar q_id: 263437
# error: can only convert an array of size 1 to a Python scalar q_id: 263438
# error: can only convert an array of size 1 to a Python scalar q_id: 263439
# error: can only convert an array of size 1 to a Python scalar q_id: 263440
# error: can only convert an array of size 1 to a Python scalar q_id: 263441
# error: can only convert an array of size 1 to a Python scalar q_id: 263442
# error: can only convert an array of size 1 to a Python scalar q_id: 263443
# error: can only convert an array of size 1 to a Python scalar q_id: 263444
# error: can only convert an array of size 1 to a Python scalar q_id: 263445
# error: can only convert an array of size 1 to a Python scalar q_id: 263446
# error: can only convert an array of size 1 to a Python scalar q_id: 263447
# error: can only convert an array of size 1 to a Python scalar q_id: 263448
# error: can only convert an array of size 1 to a Python scalar q_id: 263449
# error: can only convert an array of size 1 to a Python scalar q_id: 263450
# error: can only convert an array of size 1 to a Python scalar q_id: 263451
# error: can only convert an array of size 1 to a Python scalar q_id: 263452
# error: can only convert an array of size 1 to a Python scalar q_id: 263453
# error: can only convert an array of size 1 to a Python scalar q_id: 263454
# error: can only convert an array of size 1 to a Python scalar q_id: 263455
# error: can only convert an array of size 1 to a Python scalar q_id: 263456
# error: can only convert an array of size 1 to a Python scalar q_id: 263457
# error: can only convert an array of size 1 to a Python scalar q_id: 263458
# error: can only convert an array of size 1 to a Python scalar q_id: 263459
# error: can only convert an array of size 1 to a Python scalar q_id: 263460
# error: can only convert an array of size 1 to a Python scalar q_id: 263461
# error: can only convert an array of size 1 to a Python scalar q_id: 263462
# error: can only convert an array of size 1 to a Python scalar q_id: 263463
# error: can only convert an array of size 1 to a Python scalar q_id: 263464
# error: can only convert an array of size 1 to a Python scalar q_id: 263465
# error: can only convert an array of size 1 to a Python scalar q_id: 263466
# error: can only convert an array of size 1 to a Python scalar q_id: 263467
# error: can only convert an array of size 1 to a Python scalar q_id: 263468
# error: can only convert an array of size 1 to a Python scalar q_id: 263469
# error: can only convert an array of size 1 to a Python scalar q_id: 263470
# error: can only convert an array of size 1 to a Python scalar q_id: 263471
# error: can only convert an array of size 1 to a Python scalar q_id: 263472
# error: can only convert an array of size 1 to a Python scalar q_id: 263473
# error: can only convert an array of size 1 to a Python scalar q_id: 263474
# error: can only convert an array of size 1 to a Python scalar q_id: 263475
# error: can only convert an array of size 1 to a Python scalar q_id: 263476
# error: can only convert an array of size 1 to a Python scalar q_id: 263477
# error: can only convert an array of size 1 to a Python scalar q_id: 263478
# error: can only convert an array of size 1 to a Python scalar q_id: 263479
# error: can only convert an array of size 1 to a Python scalar q_id: 263480
# error: can only convert an array of size 1 to a Python scalar q_id: 263481
# error: can only convert an array of size 1 to a Python scalar q_id: 263482
# error: can only convert an array of size 1 to a Python scalar q_id: 263483
# error: can only convert an array of size 1 to a Python scalar q_id: 263484
# error: can only convert an array of size 1 to a Python scalar q_id: 263485
# error: can only convert an array of size 1 to a Python scalar q_id: 263486
# error: can only convert an array of size 1 to a Python scalar q_id: 263487
# error: can only convert an array of size 1 to a Python scalar q_id: 263488
# error: can only convert an array of size 1 to a Python scalar q_id: 263489
# error: can only convert an array of size 1 to a Python scalar q_id: 263490
# error: can only convert an array of size 1 to a Python scalar q_id: 263491
# error: can only convert an array of size 1 to a Python scalar q_id: 263492
# error: can only convert an array of size 1 to a Python scalar q_id: 263493
# error: can only convert an array of size 1 to a Python scalar q_id: 263494
# error: can only convert an array of size 1 to a Python scalar q_id: 263495
# error: can only convert an array of size 1 to a Python scalar q_id: 263496
# error: can only convert an array of size 1 to a Python scalar q_id: 263497
# error: can only convert an array of size 1 to a Python scalar q_id: 263498
# error: can only convert an array of size 1 to a Python scalar q_id: 263499
# error: can only convert an array of size 1 to a Python scalar q_id: 263500
# error: can only convert an array of size 1 to a Python scalar q_id: 263501
# error: can only convert an array of size 1 to a Python scalar q_id: 263502
# error: can only convert an array of size 1 to a Python scalar q_id: 263503
# error: can only convert an array of size 1 to a Python scalar q_id: 263504
# error: can only convert an array of size 1 to a Python scalar q_id: 263505
# error: can only convert an array of size 1 to a Python scalar q_id: 263506
# error: can only convert an array of size 1 to a Python scalar q_id: 263507
# error: can only convert an array of size 1 to a Python scalar q_id: 263508
# error: can only convert an array of size 1 to a Python scalar q_id: 263509
# error: can only convert an array of size 1 to a Python scalar q_id: 263510
# error: can only convert an array of size 1 to a Python scalar q_id: 263511
# error: can only convert an array of size 1 to a Python scalar q_id: 263512
# error: can only convert an array of size 1 to a Python scalar q_id: 263513
# error: can only convert an array of size 1 to a Python scalar q_id: 263514
# error: can only convert an array of size 1 to a Python scalar q_id: 263515
# error: can only convert an array of size 1 to a Python scalar q_id: 263516
# error: can only convert an array of size 1 to a Python scalar q_id: 263517
# error: can only convert an array of size 1 to a Python scalar q_id: 263518
# error: can only convert an array of size 1 to a Python scalar q_id: 263519
# error: can only convert an array of size 1 to a Python scalar q_id: 263520
# error: can only convert an array of size 1 to a Python scalar q_id: 263521
# error: can only convert an array of size 1 to a Python scalar q_id: 263522
# error: can only convert an array of size 1 to a Python scalar q_id: 263523
# error: can only convert an array of size 1 to a Python scalar q_id: 263524
# error: can only convert an array of size 1 to a Python scalar q_id: 263525
# error: can only convert an array of size 1 to a Python scalar q_id: 263526
# error: can only convert an array of size 1 to a Python scalar q_id: 263527
# error: can only convert an array of size 1 to a Python scalar q_id: 263528
# error: can only convert an array of size 1 to a Python scalar q_id: 263529
# error: can only convert an array of size 1 to a Python scalar q_id: 263530
# error: can only convert an array of size 1 to a Python scalar q_id: 263531
# error: can only convert an array of size 1 to a Python scalar q_id: 263532
# error: can only convert an array of size 1 to a Python scalar q_id: 263533
# error: can only convert an array of size 1 to a Python scalar q_id: 263534
# error: can only convert an array of size 1 to a Python scalar q_id: 263535
# error: can only convert an array of size 1 to a Python scalar q_id: 263536
# error: can only convert an array of size 1 to a Python scalar q_id: 263537
# error: can only convert an array of size 1 to a Python scalar q_id: 263538
# error: can only convert an array of size 1 to a Python scalar q_id: 263539
# error: can only convert an array of size 1 to a Python scalar q_id: 263540
# error: can only convert an array of size 1 to a Python scalar q_id: 263541
# error: can only convert an array of size 1 to a Python scalar q_id: 263542
# error: can only convert an array of size 1 to a Python scalar q_id: 263543
# error: can only convert an array of size 1 to a Python scalar q_id: 263544
# error: can only convert an array of size 1 to a Python scalar q_id: 263545
# error: can only convert an array of size 1 to a Python scalar q_id: 263546
# error: can only convert an array of size 1 to a Python scalar q_id: 263547
# error: can only convert an array of size 1 to a Python scalar q_id: 263548
# error: can only convert an array of size 1 to a Python scalar q_id: 263549
# error: can only convert an array of size 1 to a Python scalar q_id: 263550
# error: can only convert an array of size 1 to a Python scalar q_id: 263551
# error: can only convert an array of size 1 to a Python scalar q_id: 263552
# error: can only convert an array of size 1 to a Python scalar q_id: 263553
# error: can only convert an array of size 1 to a Python scalar q_id: 263554
# error: can only convert an array of size 1 to a Python scalar q_id: 263555
# error: can only convert an array of size 1 to a Python scalar q_id: 263556
# error: can only convert an array of size 1 to a Python scalar q_id: 263557
# error: can only convert an array of size 1 to a Python scalar q_id: 263558
# error: can only convert an array of size 1 to a Python scalar q_id: 263559
# error: can only convert an array of size 1 to a Python scalar q_id: 263560
# error: can only convert an array of size 1 to a Python scalar q_id: 263561
# error: can only convert an array of size 1 to a Python scalar q_id: 263562
# error: can only convert an array of size 1 to a Python scalar q_id: 263563
# error: can only convert an array of size 1 to a Python scalar q_id: 263564
# error: can only convert an array of size 1 to a Python scalar q_id: 263565
# error: can only convert an array of size 1 to a Python scalar q_id: 263566
# error: can only convert an array of size 1 to a Python scalar q_id: 263567
# error: can only convert an array of size 1 to a Python scalar q_id: 263568
# error: can only convert an array of size 1 to a Python scalar q_id: 263569
# error: can only convert an array of size 1 to a Python scalar q_id: 263570
# error: can only convert an array of size 1 to a Python scalar q_id: 263571
# error: can only convert an array of size 1 to a Python scalar q_id: 263572
# error: can only convert an array of size 1 to a Python scalar q_id: 263573
# error: can only convert an array of size 1 to a Python scalar q_id: 263574
# error: can only convert an array of size 1 to a Python scalar q_id: 263575
# error: can only convert an array of size 1 to a Python scalar q_id: 263576
# ...
# error: can only convert an array of size 1 to a Python scalar q_id: 268383
# error: can only convert an array of size 1 to a Python scalar q_id: 268384
# error: can only convert an array of size 1 to a Python scalar q_id: 268385
# error: can only convert an array of size 1 to a Python scalar q_id: 268386
# error: can only convert an array of size 1 to a Python scalar q_id: 268387
# error: can only convert an array of size 1 to a Python scalar q_id: 268388
# error: can only convert an array of size 1 to a Python scalar q_id: 268389
# error: can only convert an array of size 1 to a Python scalar q_id: 268390
# error: can only convert an array of size 1 to a Python scalar q_id: 268391
# error: can only convert an array of size 1 to a Python scalar q_id: 268392
# error: can only convert an array of size 1 to a Python scalar q_id: 268393
# error: can only convert an array of size 1 to a Python scalar q_id: 268394
# error: can only convert an array of size 1 to a Python scalar q_id: 268395
# error: can only convert an array of size 1 to a Python scalar q_id: 268396
# error: can only convert an array of size 1 to a Python scalar q_id: 268397
# error: can only convert an array of size 1 to a Python scalar q_id: 268398
# error: can only convert an array of size 1 to a Python scalar q_id: 268399
# error: can only convert an array of size 1 to a Python scalar q_id: 268400
# error: can only convert an array of size 1 to a Python scalar q_id: 268401
# error: can only convert an array of size 1 to a Python scalar q_id: 268402
# error: can only convert an array of size 1 to a Python scalar q_id: 268403
# error: can only convert an array of size 1 to a Python scalar q_id: 268404
# error: can only convert an array of size 1 to a Python scalar q_id: 268405
# error: can only convert an array of size 1 to a Python scalar q_id: 268406
# error: can only convert an array of size 1 to a Python scalar q_id: 268407
# error: can only convert an array of size 1 to a Python scalar q_id: 268408
# error: can only convert an array of size 1 to a Python scalar q_id: 268409
# error: can only convert an array of size 1 to a Python scalar q_id: 268410
# error: can only convert an array of size 1 to a Python scalar q_id: 268411
# error: can only convert an array of size 1 to a Python scalar q_id: 268412
# error: can only convert an array of size 1 to a Python scalar q_id: 268413
# error: can only convert an array of size 1 to a Python scalar q_id: 268414
# error: can only convert an array of size 1 to a Python scalar q_id: 268415
# error: can only convert an array of size 1 to a Python scalar q_id: 268416
# error: can only convert an array of size 1 to a Python scalar q_id: 268417
# error: can only convert an array of size 1 to a Python scalar q_id: 268418
# error: can only convert an array of size 1 to a Python scalar q_id: 268419
# error: can only convert an array of size 1 to a Python scalar q_id: 268420
# error: can only convert an array of size 1 to a Python scalar q_id: 268421
# error: can only convert an array of size 1 to a Python scalar q_id: 268422
# error: can only convert an array of size 1 to a Python scalar q_id: 268423
# error: can only convert an array of size 1 to a Python scalar q_id: 268424
# error: can only convert an array of size 1 to a Python scalar q_id: 268425
# error: can only convert an array of size 1 to a Python scalar q_id: 268426
# error: can only convert an array of size 1 to a Python scalar q_id: 268427
# error: can only convert an array of size 1 to a Python scalar q_id: 268428
# error: can only convert an array of size 1 to a Python scalar q_id: 268429
# error: can only convert an array of size 1 to a Python scalar q_id: 268430
# error: can only convert an array of size 1 to a Python scalar q_id: 268431
# error: can only convert an array of size 1 to a Python scalar q_id: 268432
# error: can only convert an array of size 1 to a Python scalar q_id: 268433
# error: can only convert an array of size 1 to a Python scalar q_id: 268434
# error: can only convert an array of size 1 to a Python scalar q_id: 268435
# error: can only convert an array of size 1 to a Python scalar q_id: 268436
# error: can only convert an array of size 1 to a Python scalar q_id: 268437
# error: can only convert an array of size 1 to a Python scalar q_id: 268438
# error: can only convert an array of size 1 to a Python scalar q_id: 268439
# error: can only convert an array of size 1 to a Python scalar q_id: 268440
# error: can only convert an array of size 1 to a Python scalar q_id: 268441
# error: can only convert an array of size 1 to a Python scalar q_id: 268442
# error: can only convert an array of size 1 to a Python scalar q_id: 268443
# error: can only convert an array of size 1 to a Python scalar q_id: 268444
# error: can only convert an array of size 1 to a Python scalar q_id: 268445
# error: can only convert an array of size 1 to a Python scalar q_id: 268446
# error: can only convert an array of size 1 to a Python scalar q_id: 268447
# error: can only convert an array of size 1 to a Python scalar q_id: 268448
# error: can only convert an array of size 1 to a Python scalar q_id: 268449
# error: can only convert an array of size 1 to a Python scalar q_id: 268450
# error: can only convert an array of size 1 to a Python scalar q_id: 268451
# error: can only convert an array of size 1 to a Python scalar q_id: 268452
# error: can only convert an array of size 1 to a Python scalar q_id: 268453
# error: can only convert an array of size 1 to a Python scalar q_id: 268454
# error: can only convert an array of size 1 to a Python scalar q_id: 268455
# error: can only convert an array of size 1 to a Python scalar q_id: 268456
# error: can only convert an array of size 1 to a Python scalar q_id: 268457
# error: can only convert an array of size 1 to a Python scalar q_id: 268458
# error: can only convert an array of size 1 to a Python scalar q_id: 268459
# error: can only convert an array of size 1 to a Python scalar q_id: 268460
# error: can only convert an array of size 1 to a Python scalar q_id: 268461
# error: can only convert an array of size 1 to a Python scalar q_id: 268462
# error: can only convert an array of size 1 to a Python scalar q_id: 268463
# error: can only convert an array of size 1 to a Python scalar q_id: 268464
# error: can only convert an array of size 1 to a Python scalar q_id: 268465
# error: can only convert an array of size 1 to a Python scalar q_id: 268466
# error: can only convert an array of size 1 to a Python scalar q_id: 268467
# error: can only convert an array of size 1 to a Python scalar q_id: 268468
# error: can only convert an array of size 1 to a Python scalar q_id: 268469
# error: can only convert an array of size 1 to a Python scalar q_id: 268470
# error: can only convert an array of size 1 to a Python scalar q_id: 268471
# error: can only convert an array of size 1 to a Python scalar q_id: 268472
# error: can only convert an array of size 1 to a Python scalar q_id: 268473
# error: can only convert an array of size 1 to a Python scalar q_id: 268474
# error: can only convert an array of size 1 to a Python scalar q_id: 268475
# error: can only convert an array of size 1 to a Python scalar q_id: 268476
# error: can only convert an array of size 1 to a Python scalar q_id: 268477
# error: can only convert an array of size 1 to a Python scalar q_id: 268478
# error: can only convert an array of size 1 to a Python scalar q_id: 268479
# error: can only convert an array of size 1 to a Python scalar q_id: 268480
# error: can only convert an array of size 1 to a Python scalar q_id: 268481
# error: can only convert an array of size 1 to a Python scalar q_id: 268482
# error: can only convert an array of size 1 to a Python scalar q_id: 268483
# error: can only convert an array of size 1 to a Python scalar q_id: 268484
# error: can only convert an array of size 1 to a Python scalar q_id: 268485
# error: can only convert an array of size 1 to a Python scalar q_id: 268486
# error: can only convert an array of size 1 to a Python scalar q_id: 268487
# error: can only convert an array of size 1 to a Python scalar q_id: 268488
# error: can only convert an array of size 1 to a Python scalar q_id: 268489
# error: can only convert an array of size 1 to a Python scalar q_id: 268490
# error: can only convert an array of size 1 to a Python scalar q_id: 268491
# error: can only convert an array of size 1 to a Python scalar q_id: 268492
# error: can only convert an array of size 1 to a Python scalar q_id: 268493
# error: can only convert an array of size 1 to a Python scalar q_id: 268494
# error: can only convert an array of size 1 to a Python scalar q_id: 268495
# error: can only convert an array of size 1 to a Python scalar q_id: 268496
# error: can only convert an array of size 1 to a Python scalar q_id: 268497
# error: can only convert an array of size 1 to a Python scalar q_id: 268498
# error: can only convert an array of size 1 to a Python scalar q_id: 268499
# error: can only convert an array of size 1 to a Python scalar q_id: 268500
# error: can only convert an array of size 1 to a Python scalar q_id: 268501
# error: can only convert an array of size 1 to a Python scalar q_id: 268502
# error: can only convert an array of size 1 to a Python scalar q_id: 268503
# error: can only convert an array of size 1 to a Python scalar q_id: 268504
# error: can only convert an array of size 1 to a Python scalar q_id: 268505
# error: can only convert an array of size 1 to a Python scalar q_id: 268506
# error: can only convert an array of size 1 to a Python scalar q_id: 268507
# error: can only convert an array of size 1 to a Python scalar q_id: 268508
# error: can only convert an array of size 1 to a Python scalar q_id: 268509
# error: can only convert an array of size 1 to a Python scalar q_id: 268510
# error: can only convert an array of size 1 to a Python scalar q_id: 268511
# error: can only convert an array of size 1 to a Python scalar q_id: 268512
# error: can only convert an array of size 1 to a Python scalar q_id: 268513
# error: can only convert an array of size 1 to a Python scalar q_id: 268514
# error: can only convert an array of size 1 to a Python scalar q_id: 268515
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 268591/268591 [23:10<00:00, 193.18it/s]
# error: can only convert an array of size 1 to a Python scalar q_id: 268516
# error: can only convert an array of size 1 to a Python scalar q_id: 268517
# error: can only convert an array of size 1 to a Python scalar q_id: 268518
# error: can only convert an array of size 1 to a Python scalar q_id: 268519
# error: can only convert an array of size 1 to a Python scalar q_id: 268520
# error: can only convert an array of size 1 to a Python scalar q_id: 268521
# error: can only convert an array of size 1 to a Python scalar q_id: 268522
# error: can only convert an array of size 1 to a Python scalar q_id: 268523
# error: can only convert an array of size 1 to a Python scalar q_id: 268524
# error: can only convert an array of size 1 to a Python scalar q_id: 268525
# error: can only convert an array of size 1 to a Python scalar q_id: 268526
# error: can only convert an array of size 1 to a Python scalar q_id: 268527
# error: can only convert an array of size 1 to a Python scalar q_id: 268528
# error: can only convert an array of size 1 to a Python scalar q_id: 268529
# error: can only convert an array of size 1 to a Python scalar q_id: 268530
# error: can only convert an array of size 1 to a Python scalar q_id: 268531
# error: can only convert an array of size 1 to a Python scalar q_id: 268532
# error: can only convert an array of size 1 to a Python scalar q_id: 268533
# error: can only convert an array of size 1 to a Python scalar q_id: 268534
# error: can only convert an array of size 1 to a Python scalar q_id: 268535
# error: can only convert an array of size 1 to a Python scalar q_id: 268536
# error: can only convert an array of size 1 to a Python scalar q_id: 268537
# error: can only convert an array of size 1 to a Python scalar q_id: 268538
# error: can only convert an array of size 1 to a Python scalar q_id: 268539
# error: can only convert an array of size 1 to a Python scalar q_id: 268540
# error: can only convert an array of size 1 to a Python scalar q_id: 268541
# error: can only convert an array of size 1 to a Python scalar q_id: 268542
# error: can only convert an array of size 1 to a Python scalar q_id: 268543
# error: can only convert an array of size 1 to a Python scalar q_id: 268544
# error: can only convert an array of size 1 to a Python scalar q_id: 268545
# error: can only convert an array of size 1 to a Python scalar q_id: 268546
# error: can only convert an array of size 1 to a Python scalar q_id: 268547
# error: can only convert an array of size 1 to a Python scalar q_id: 268548
# error: can only convert an array of size 1 to a Python scalar q_id: 268549
# error: can only convert an array of size 1 to a Python scalar q_id: 268550
# error: can only convert an array of size 1 to a Python scalar q_id: 268551
# error: can only convert an array of size 1 to a Python scalar q_id: 268552
# error: can only convert an array of size 1 to a Python scalar q_id: 268553
# error: can only convert an array of size 1 to a Python scalar q_id: 268554
# error: can only convert an array of size 1 to a Python scalar q_id: 268555
# error: can only convert an array of size 1 to a Python scalar q_id: 268556
# error: can only convert an array of size 1 to a Python scalar q_id: 268557
# error: can only convert an array of size 1 to a Python scalar q_id: 268558
# error: can only convert an array of size 1 to a Python scalar q_id: 268559
# error: can only convert an array of size 1 to a Python scalar q_id: 268560
# error: can only convert an array of size 1 to a Python scalar q_id: 268561
# error: can only convert an array of size 1 to a Python scalar q_id: 268562
# error: can only convert an array of size 1 to a Python scalar q_id: 268563
# error: can only convert an array of size 1 to a Python scalar q_id: 268564
# error: can only convert an array of size 1 to a Python scalar q_id: 268565
# error: can only convert an array of size 1 to a Python scalar q_id: 268566
# error: can only convert an array of size 1 to a Python scalar q_id: 268567
# error: can only convert an array of size 1 to a Python scalar q_id: 268568
# error: can only convert an array of size 1 to a Python scalar q_id: 268569
# error: can only convert an array of size 1 to a Python scalar q_id: 268570
# error: can only convert an array of size 1 to a Python scalar q_id: 268571
# error: can only convert an array of size 1 to a Python scalar q_id: 268572
# error: can only convert an array of size 1 to a Python scalar q_id: 268573
# error: can only convert an array of size 1 to a Python scalar q_id: 268574
# error: can only convert an array of size 1 to a Python scalar q_id: 268575
# error: can only convert an array of size 1 to a Python scalar q_id: 268576
# error: can only convert an array of size 1 to a Python scalar q_id: 268577
# error: can only convert an array of size 1 to a Python scalar q_id: 268578
# error: can only convert an array of size 1 to a Python scalar q_id: 268579
# error: can only convert an array of size 1 to a Python scalar q_id: 268580
# error: can only convert an array of size 1 to a Python scalar q_id: 268581
# error: can only convert an array of size 1 to a Python scalar q_id: 268582
# error: can only convert an array of size 1 to a Python scalar q_id: 268583
# error: can only convert an array of size 1 to a Python scalar q_id: 268584
# error: can only convert an array of size 1 to a Python scalar q_id: 268585
# error: can only convert an array of size 1 to a Python scalar q_id: 268586
# error: can only convert an array of size 1 to a Python scalar q_id: 268587
# error: can only convert an array of size 1 to a Python scalar q_id: 268588
# error: can only convert an array of size 1 to a Python scalar q_id: 268589
# error: can only convert an array of size 1 to a Python scalar q_id: 268590
# error: can only convert an array of size 1 to a Python scalar q_id: 268591
# mode: total length: 262936

# %% [markdown]
# # data/medical-books-master

# %%
def find_pdfs(directory):
    pdf_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".pdf"):
                pdf_files.append(os.path.join(root, file))
    return pdf_files


def deal_file(path, name='', mode='train'):
    doc = fitz.open(path)
    lenXREF = doc.xrefLength()
    print("文件名:{}, 页数: {}, 对象: {}".format(path, len(doc), lenXREF - 1))
    length = 0
    results = []
    lines = []
    for i, page in enumerate(doc):
        p = page.get_text().strip()
        for line in p.split('\n'):
            line = line.replace('. .', '')
            line = line.replace('�', '')
            line = line.replace('  ', '')
            if not line.strip(): continue
            length += len(line)
            if length > 1000:
                text = '\n'.join(lines)
                pos_tags = char_pos_tag(text)
                tokens, poss = zip(*pos_tags)
                assert len(tokens) == len(text) == len(poss)
                result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                          'name': name, 'mode': mode}
                results.append(result)
                length = len(line)
                lines = []
            lines.append(line)
    if len(lines):
        text = '\n'.join(lines)
        pos_tags = char_pos_tag(text)
        tokens, poss = zip(*pos_tags)
        assert len(tokens) == len(text) == len(poss)
        result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                  'name': name, 'mode': mode}
        results.append(result)
    return results


pdf_dir = epath.Path("../data/medical-books-master")
pdf_files = find_pdfs(pdf_dir)

name = 'books.pdf' 
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')

for pdf_file in pdf_files[1:]:
    data = deal_file(pdf_file, name=pdf_file, mode='total')
    print(f'length: {len(data)}')
    if isinstance(data, str):
        data = [data]
    for d in data:
        writer.write(f'{d}\n')
# Out:
# 文件名:../data/medical-books-master/临床心电图详解与诊断/main.pdf, 页数: 613, 对象: 6947
# length: 435
# 文件名:../data/medical-books-master/X线读片指南/main.pdf, 页数: 403, 对象: 2852
# length: 244
# 文件名:../data/medical-books-master/ICU主治医师手册/main.pdf, 页数: 692, 对象: 7558
# length: 793
# 文件名:../data/medical-books-master/内科治疗指南/main.pdf, 页数: 480, 对象: 3365
# length: 444
# 文件名:../data/medical-books-master/临床药物治疗学/main.pdf, 页数: 336, 对象: 4559
# length: 310
# 文件名:../data/medical-books-master/急诊内科学/main.pdf, 页数: 1904, 对象: 23445
# length: 1862
# 文件名:../data/medical-books-master/药理学/main.pdf, 页数: 36, 对象: 333
# length: 17
# 文件名:../data/medical-books-master/腹部影像解剖图谱/main.pdf, 页数: 157, 对象: 874
# length: 10
# 文件名:../data/medical-books-master/内科疾病鉴别诊断学/main.pdf, 页数: 1268, 对象: 15583
# length: 1250
# 文件名:../data/medical-books-master/免疫学/main.pdf, 页数: 245, 对象: 2060
# length: 222
# 文件名:../data/medical-books-master/精神病学/main.pdf, 页数: 417, 对象: 4038
# length: 447
# 文件名:../data/medical-books-master/病理学/main.pdf, 页数: 355, 对象: 5047
# length: 278

# %%
def deal_file(docx_path, name='', mode='train'):
    doc = Document(docx_path)
    results = []
    length = 0
    lines = []
    for paragraph in doc.paragraphs:
        for line in paragraph.text.split('\n'):
            line = line.replace('. .', '')
            line = line.replace('�', '')
            line = line.replace('  ', '')
            if not line.strip(): continue
            length += len(line)
            if length > 1000:
                text = '\n'.join(lines)
                pos_tags = char_pos_tag(text)
                tokens, poss = zip(*pos_tags)
                assert len(tokens) == len(text) == len(poss)
                result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                          'name': name, 'mode': mode}
                results.append(result)
                length = len(line)
                lines = []
            lines.append(line)
    if len(lines):
        text = '\n'.join(lines)
        pos_tags = char_pos_tag(text)
        tokens, poss = zip(*pos_tags)
        assert len(tokens) == len(text) == len(poss)
        result = {'text': text, 'tokens': tokens, 'poss': poss, 'ners': [], 'length': len(text), 
                  'name': name, 'mode': mode}
        results.append(result)
    return results


path = '../data/医疗书word/14748064.docx'
text = deal_file(path, name=path, mode='total')

name = 'books.docx'
write_dir = epath.Path('data')
os.makedirs(write_dir, exist_ok=True)
writer_path = write_dir / f'{name}.jsonl'
writer = writer_path.open('w')
read_dir = epath.Path('../data/医疗书word/')
files = os.listdir(read_dir)
for file in files:
    abs_path = read_dir / file
    data = deal_file(abs_path, name=name, mode='total')
    print(f'file: {file} length: {len(data)}')
    if isinstance(data, str):
        data = [data]
    for d in data:
        writer.write(f'{d}\n')

writer.close()
# Out:
# file: 14748064.docx length: 362
# file: 糖尿病中医防治指南解读_12333379.docx length: 717
# file: 仝小林经方新用十六讲.docx length: 284
# file: 维新医集  仝小林中医新论.docx length: 129
# file: 脾瘅新论  代谢综合征的中医认识及治疗_14568528.docx length: 346
# file: 糖尿病并发症中医诊疗学_14421290.docx length: 428
# file: 方药量效学_13279812.docx length: 420
# file: 糖尿病并发症中医诊疗学.docx length: 426
# file: 名老中医糖尿病辨治枢要.docx length: 193
# file: 方药量效关系名医汇讲.docx length: 136
# file: 糖尿病中医药临床循证实践指南_14056749(1).docx length: 247
# file: 糖尿病中医药临床循证实践指南_14056749.docx length: 247
